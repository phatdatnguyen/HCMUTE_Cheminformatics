# %% [markdown]
# # Chapter 8: Calculation of Molecular Properties

# %% [markdown]
# ## 8.2. Calculation of Potential Energy of Reaction Intermediates

# %% [markdown]
# Computational methods allows the calculation of potential energy of reaction intermediates such as cation, anion, and free radical.

# %% [markdown]
# ### 8.2.1. Calculation of Potential Energy of Cations

# %% [markdown]
# In the following section, we will calculate the potential energies of different allyic cations:

# %%
# Import modules
import os
import numpy as np
import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit.Chem import AllChem, Draw
from utils import View3DModel
import psi4
import py3Dmol
from tqdm import tqdm

# %%
# Create the cation
cation1 = Chem.MolFromSmiles('[CH3+]')
cation2 = Chem.MolFromSmiles('[CH2+](C)')
cation3 = Chem.MolFromSmiles('[CH+](C)(C)')
cation4 = Chem.MolFromSmiles('[C+](C)(C)(C)')
cation5 = Chem.MolFromSmiles('[C+](C1=CC=CC=C1)(C)(C)')
cations = [cation1, cation2, cation3, cation4, cation5]

Draw.MolsToGridImage(cations)

# %%
# Create the molecules
mol1 = Chem.MolFromSmiles('C')
mol2 = Chem.MolFromSmiles('CC')
mol3 = Chem.MolFromSmiles('C(C)(C)')
mol4 = Chem.MolFromSmiles('C(C)(C)(C)')
mol5 = Chem.MolFromSmiles('C(C1=CC=CC=C1)(C)C')
mols = [mol1, mol2, mol3, mol4, mol5]

Draw.MolsToGridImage(mols)

# %%
# Set the number of threads and memory limit
psi4.set_num_threads(16)
psi4.set_memory(16*1024*1024*1024) # 16 GB
# Out:
# 17179869184

# %%
# Set calculation options
psi4.set_options({
    'BASIS': '6-31++G**',
    'SCF_TYPE': 'DF',
    'REFERENCE': 'RHF'
})

# %%
# Define a function to generate xyz string with charge and multiplicity
def generate_xyz_string(mol, charge, multiplicity):
    # Get atom information
    atoms = mol.GetAtoms()
    xyz_lines = []
    for atom in atoms:
        pos = mol.GetConformer().GetAtomPosition(atom.GetIdx())
        xyz_lines.append(f"{atom.GetSymbol()} {pos.x} {pos.y} {pos.z}")

    # Construct the XYZ string
    xyz_string = f"{charge} {multiplicity}\n" + "\n".join(xyz_lines)
    return xyz_string

# %%
cation_energies = []
cation_wfns = []

# Optimize the geometries and calculate the energies for all cations
progress_bar = tqdm(cations)
for mol in progress_bar:
    smiles = Chem.MolToSmiles(mol)
    progress_bar.set_description(f'SMILES: {smiles}. Optimizing geometry...')
    
    # Prepare the molecule
    mol = Chem.AddHs(mol)
    AllChem.EmbedMolecule(mol)
    AllChem.UFFOptimizeMolecule(mol, maxIters=200)
    
    # Write the geometry to XYZ string
    charge = 1  # For cation
    multiplicity = 1  # Singlet state
    xyz_string = generate_xyz_string(mol, charge, multiplicity)

    # Get the psi4 geometry
    geometry = psi4.geometry(xyz_string)
    
    # Run geometry optimization
    max_iters = 500
    energy, wfn = psi4.optimize('b3lyp', molecule=geometry, optking__geom_maxiter=max_iters, return_wfn=True)
    cation_energies.append(energy * psi4.constants.hartree2kcalmol)
    cation_wfns.append(wfn)
# Out:
# SMILES: [CH2+]C. Optimizing geometry...:  20%|████████▌                                  | 1/5 [00:02<00:11,  2.98s/it]
# Optimizer: Optimization complete!
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.09e-03
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 6.38e-04
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 6.05e-07
#
# 	Energy has increased in a minimization.
# 	Energy ratio indicates iffy step.
# 	Intrafrag trust radius decreased to 2.500e-01.
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.33e-05
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  3.833e-07 	Max(dx):  9.434e-07 	RMS(dq):  2.820e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.32e-06
#
# SMILES: C[CH+]C. Optimizing geometry...:  40%|█████████████████▏                         | 2/5 [00:16<00:27,  9.26s/it]
# Optimizer: Optimization complete!
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 6.59e-04
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  2.118e-06 	Max(dx):  5.661e-06 	RMS(dq):  2.411e-04
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.41e-04
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.07e-07
#
# SMILES: C[C+](C)C. Optimizing geometry...:  60%|████████████████████████▌                | 3/5 [00:33<00:25, 12.92s/it]
# Optimizer: Optimization complete!
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.52e-04
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  2.559e-06 	Max(dx):  1.041e-05 	RMS(dq):  8.569e-05
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 8.57e-05
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 7.21e-08
#
# SMILES: C[C+](C)c1ccccc1. Optimizing geometry...:  80%|███████████████████████████▏      | 4/5 [01:00<00:18, 18.51s/it]
# Optimizer: Optimization complete!
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  2.501e-06 	Max(dx):  7.703e-06 	RMS(dq):  8.014e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 7.70e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  4.153e-06 	Max(dx):  1.321e-05 	RMS(dq):  1.369e-05
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.35e-05
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  4.630e-06 	Max(dx):  1.835e-05 	RMS(dq):  4.072e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.49e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.839e-06 	Max(dx):  8.106e-06 	RMS(dq):  3.099e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.71e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  2.309e-06 	Max(dx):  1.183e-05 	RMS(dq):  3.726e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.12e-06
#
# SMILES: C[C+](C)c1ccccc1. Optimizing geometry...: 100%|██████████████████████████████████| 5/5 [02:40<00:00, 32.17s/it]
# Optimizer: Optimization complete!

# %%
mol_energies = []
mol_wfns = []

# Optimize the geometries and calculate the energies for all molecules
progress_bar = tqdm(mols)
for mol in progress_bar:
    smiles = Chem.MolToSmiles(mol)
    progress_bar.set_description(f'SMILES: {smiles}. Optimizing geometry...')
    
    # Prepare the molecule
    mol = Chem.AddHs(mol)
    AllChem.EmbedMolecule(mol)
    AllChem.UFFOptimizeMolecule(mol, maxIters=200)
    
    # Write the geometry to XYZ string
    xyz_string = Chem.MolToXYZBlock(mol)

    # Get the psi4 geometry
    geometry = psi4.geometry(xyz_string)
    
    # Run geometry optimization
    max_iters = 500
    energy, wfn = psi4.optimize('b3lyp', molecule=geometry, optking__geom_maxiter=max_iters, return_wfn=True)
    mol_energies.append(energy * psi4.constants.hartree2kcalmol)
    mol_wfns.append(wfn)
# Out:
# SMILES: CC. Optimizing geometry...:  20%|█████████▌                                      | 1/5 [00:02<00:11,  2.81s/it]
# Optimizer: Optimization complete!
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.52e-04
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 9.42e-07
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.55e-07
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 9.70e-08
#
# SMILES: CCC. Optimizing geometry...:  40%|██████████████████▊                            | 2/5 [00:11<00:19,  6.41s/it]
# Optimizer: Optimization complete!
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.89e-04
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.90e-06
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 4.42e-07
#
# SMILES: CC(C)C. Optimizing geometry...:  60%|██████████████████████████▍                 | 3/5 [00:25<00:19,  9.62s/it]
# Optimizer: Optimization complete!
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 7.75e-09
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.43e-10
#
# 	Denominators (dg)(dq) or (dq)(dq) are very small.
# 	Skipping Hessian update for step 4.
# 	Energy has increased in a minimization.
# 	Energy ratio indicates iffy step.
# 	Intrafrag trust radius decreased to 2.500e-01.
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 9.85e-10
#
# 	Denominators (dg)(dq) or (dq)(dq) are very small.
# 	Skipping Hessian update for step 6.
# 	Denominators (dg)(dq) or (dq)(dq) are very small.
# 	Skipping Hessian update for step 4.
# 	Energy has increased in a minimization.
# 	Energy ratio indicates iffy step.
# 	Intrafrag trust radius decreased to 6.250e-02.
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 7.35e-11
#
# SMILES: CC(C)c1ccccc1. Optimizing geometry...:  80%|█████████████████████████████▌       | 4/5 [01:05<00:21, 21.81s/it]
# Optimizer: Optimization complete!
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.142e-06 	Max(dx):  3.711e-06 	RMS(dq):  1.040e-04
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.904e-06 	Max(dx):  5.597e-06 	RMS(dq):  1.579e-05
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.57e-05
#
# 	Energy has increased in a minimization.
# 	Energy ratio indicates iffy step.
# 	Intrafrag trust radius decreased to 2.500e-01.
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  2.844e-06 	Max(dx):  7.769e-06 	RMS(dq):  2.250e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.74e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  3.063e-06 	Max(dx):  7.967e-06 	RMS(dq):  3.935e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.50e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  3.671e-06 	Max(dx):  1.254e-05 	RMS(dq):  3.298e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.91e-06
#
# SMILES: CC(C)c1ccccc1. Optimizing geometry...: 100%|█████████████████████████████████████| 5/5 [02:58<00:00, 35.73s/it]
# Optimizer: Optimization complete!

# %%
# Calculate the energy differences between the cations and the molecules
cation_energies = np.array(cation_energies)
mol_energies = np.array(mol_energies)
energy_diff = cation_energies - mol_energies

# Use methyl free radical as the reference
energy_diff = energy_diff - energy_diff[0]

# Plot the energy differences
x = range(len(energy_diff))
plt.bar(x, energy_diff)
plt.xlabel('Cation')
plt.ylabel('Energy difference (kcal/mol)')
plt.axhline(0, color='black')

# %% [markdown]
# ### 8.2.2. Calculation of Potential Energy of Anion

# %% [markdown]
# In the following section, we will calculate the potential energies of different benzoic acids and benzoate anions in order to compare there acidity/basicity:

# %%
# Import modules
import os
import numpy as np
import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit.Chem import AllChem, Draw
from utils import View3DModel, WriteXYZString # same as generate_xyz_string() function above
import psi4
import py3Dmol
from tqdm import tqdm

# %%
# Create the core molecules
core_acid_mol = Chem.MolFromSmiles('c1cc(C(=O)O)ccc1*')
core_base_mol = Chem.MolFromSmiles('c1cc(C(=O)[O-])ccc1*')

# %%
Draw.MolsToGridImage([core_acid_mol, core_base_mol])

# %%
# Define substituents
substituents = ['[H]', 'C', 'Cl', 'O', 'C(=O)C']

# %%
# Generate acids band bases
acids = []
bases = []

for substituent in substituents:
    # Create a copy of the core molecules
    core_acid_mol_copy = Chem.Mol(core_acid_mol)
    core_base_mol_copy = Chem.Mol(core_base_mol)

    # Replace a hydrogen atom with the substituent
    subst_mol = Chem.MolFromSmiles(substituent)
    subst_acid_mol_smiles = Chem.MolToSmiles(Chem.rdmolops.ReplaceSubstructs(core_acid_mol_copy, Chem.MolFromSmarts('[#0]'), subst_mol)[0])
    subst_base_mol_smiles = Chem.MolToSmiles(Chem.rdmolops.ReplaceSubstructs(core_base_mol_copy, Chem.MolFromSmarts('[#0]'), subst_mol)[0])
    acids.append(Chem.MolFromSmiles(subst_acid_mol_smiles))
    bases.append(Chem.MolFromSmiles(subst_base_mol_smiles))
# Out:
# [16:03:23] WARNING: not removing hydrogen atom without neighbors

# %%
Draw.MolsToGridImage(acids)

# %%
Draw.MolsToGridImage(bases)

# %%
# Set the number of threads and set memory limit
psi4.set_num_threads(32)
psi4.set_memory(16*1024*1024*1024) # 16 GB
# Out:
# 17179869184

# %%
# Set calculation options
psi4.set_options({
    'BASIS': '6-31G*',
    'SCF_TYPE': 'DF',
    'REFERENCE': 'RHF'
})

# %%
acid_energies = []
acid_wfns = []

# Optimize the geometries and calculate the energies for all acids
progress_bar = tqdm(acids)
for mol in progress_bar:
    smiles = Chem.MolToSmiles(mol)
    progress_bar.set_description(f'SMILES: {smiles}. Optimizing geometry...')
    
    # Prepare the molecule
    mol = Chem.AddHs(mol)
    AllChem.EmbedMolecule(mol)
    AllChem.UFFOptimizeMolecule(mol, maxIters=200)
    
    # Write the geometry to XYZ string
    xyz_string = Chem.MolToXYZBlock(mol)

    # Get the psi4 geometry
    geometry = psi4.geometry(xyz_string)
    
    # Run geometry optimization
    max_iters = 500
    energy, wfn = psi4.optimize('b3lyp', molecule=geometry, optking__geom_maxiter=max_iters, return_wfn=True)
    acid_energies.append(energy * psi4.constants.hartree2kcalmol)
    acid_wfns.append(wfn)
# Out:
# SMILES: O=C(O)c1ccccc1. Optimizing geometry...:   0%|                                            | 0/5 [00:00<?, ?it/s]	Unable to completely converge to displaced geometry.
# 	RMS(dx):  3.116e-07 	Max(dx):  1.224e-06 	RMS(dq):  7.750e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 7.75e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  3.230e-07 	Max(dx):  8.174e-07 	RMS(dq):  5.492e-07
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 5.39e-07
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  2.138e-06 	Max(dx):  5.707e-06 	RMS(dq):  2.029e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.50e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.933e-06 	Max(dx):  6.572e-06 	RMS(dq):  3.297e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.82e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  9.561e-07 	Max(dx):  2.976e-06 	RMS(dq):  1.101e-05
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.10e-05
#
# 	Energy has increased in a minimization.
# 	Energy ratio indicates iffy step.
# 	Intrafrag trust radius decreased to 2.500e-01.
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  2.225e-06 	Max(dx):  7.389e-06 	RMS(dq):  8.090e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 8.08e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  6.838e-06 	Max(dx):  1.984e-05 	RMS(dq):  6.161e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 4.08e-06
#
# SMILES: Cc1ccc(C(=O)O)cc1. Optimizing geometry...:  20%|██████▌                          | 1/5 [01:08<04:32, 68.05s/it]
# Optimizer: Optimization complete!
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.51e-05
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 9.36e-05
#
# 	Energy has increased in a minimization.
# 	Energy ratio indicates iffy step.
# 	Intrafrag trust radius decreased to 2.500e-01.
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 9.64e-05
#
# 	Energy has increased in a minimization.
# 	Energy ratio indicates iffy step.
# 	Intrafrag trust radius decreased to 1.875e-01.
# SMILES: O=C(O)c1ccc(Cl)cc1. Optimizing geometry...:  40%|████████████▊                   | 2/5 [02:37<04:02, 80.69s/it]
# Optimizer: Optimization complete!
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  2.116e-06 	Max(dx):  8.510e-06 	RMS(dq):  3.633e-06
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.000e-06 	Max(dx):  3.472e-06 	RMS(dq):  1.918e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.67e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  7.107e-06 	Max(dx):  2.298e-05 	RMS(dq):  3.811e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.05e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.207e-06 	Max(dx):  4.654e-06 	RMS(dq):  4.017e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.43e-06
#
# 	Energy has increased in a minimization.
# 	Energy ratio indicates iffy step.
# 	Intrafrag trust radius decreased to 2.500e-01.
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  9.492e-07 	Max(dx):  3.912e-06 	RMS(dq):  1.051e-05
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.04e-05
#
# SMILES: O=C(O)c1ccc(O)cc1. Optimizing geometry...:  60%|███████████████████▊             | 3/5 [03:39<02:24, 72.10s/it]
# Optimizer: Optimization complete!
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  2.199e-07 	Max(dx):  7.328e-07 	RMS(dq):  4.626e-06
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  3.657e-06 	Max(dx):  1.612e-05 	RMS(dq):  3.043e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.96e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.126e-06 	Max(dx):  4.989e-06 	RMS(dq):  2.691e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.33e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  4.950e-06 	Max(dx):  1.914e-05 	RMS(dq):  4.687e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.20e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  5.401e-06 	Max(dx):  1.992e-05 	RMS(dq):  9.407e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 9.28e-06
#
# 	Energy has increased in a minimization.
# 	Energy ratio indicates iffy step.
# 	Intrafrag trust radius decreased to 2.500e-01.
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  5.470e-06 	Max(dx):  1.993e-05 	RMS(dq):  7.609e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 7.54e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  4.546e-06 	Max(dx):  2.157e-05 	RMS(dq):  5.322e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 5.14e-06
#
# SMILES: CC(=O)c1ccc(C(=O)O)cc1. Optimizing geometry...:  80%|██████████████████████▍     | 4/5 [05:06<01:17, 77.96s/it]
# Optimizer: Optimization complete!
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  8.215e-07 	Max(dx):  2.416e-06 	RMS(dq):  4.560e-05
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 4.56e-05
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.666e-06 	Max(dx):  4.879e-06 	RMS(dq):  2.067e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 9.68e-07
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  9.461e-06 	Max(dx):  2.104e-05 	RMS(dq):  3.825e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.27e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  9.050e-06 	Max(dx):  2.256e-05 	RMS(dq):  3.780e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.47e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  2.266e-06 	Max(dx):  7.783e-06 	RMS(dq):  1.089e-05
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.08e-05
#
# 	Energy has increased in a minimization.
# 	Energy ratio indicates iffy step.
# 	Intrafrag trust radius decreased to 2.500e-01.
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  5.133e-06 	Max(dx):  1.777e-05 	RMS(dq):  9.021e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 8.58e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  4.862e-06 	Max(dx):  1.340e-05 	RMS(dq):  4.918e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.62e-06
#
# SMILES: CC(=O)c1ccc(C(=O)O)cc1. Optimizing geometry...: 100%|████████████████████████████| 5/5 [07:28<00:00, 89.68s/it]
# Optimizer: Optimization complete!

# %%
base_energies = []
base_wfns = []

# Optimize the geometries and calculate the energies for all bases
progress_bar = tqdm(bases)
for mol in progress_bar:
    smiles = Chem.MolToSmiles(mol)
    progress_bar.set_description(f'SMILES: {smiles}. Optimizing geometry...')
    
    # Prepare the molecule
    mol = Chem.AddHs(mol)
    AllChem.EmbedMolecule(mol)
    AllChem.UFFOptimizeMolecule(mol, maxIters=200)
    
    # Write the geometry to XYZ string
    charge = -1  # For anion
    multiplicity = 1  # Singlet state
    xyz_string = WriteXYZString(mol, charge, multiplicity)

    # Get the psi4 geometry
    geometry = psi4.geometry(xyz_string)
    
    # Run geometry optimization
    max_iters = 500
    energy, wfn = psi4.optimize('b3lyp', molecule=geometry, optking__geom_maxiter=max_iters, return_wfn=True)
    base_energies.append(energy * psi4.constants.hartree2kcalmol)
    base_wfns.append(wfn)
# Out:
# SMILES: O=C([O-])c1ccccc1. Optimizing geometry...:   0%|                                         | 0/5 [00:00<?, ?it/s]	Unable to completely converge to displaced geometry.
# 	RMS(dx):  7.810e-07 	Max(dx):  2.100e-06 	RMS(dq):  3.572e-06
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  3.319e-06 	Max(dx):  1.086e-05 	RMS(dq):  4.224e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 4.22e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.621e-06 	Max(dx):  6.392e-06 	RMS(dq):  2.783e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.40e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.555e-06 	Max(dx):  7.345e-06 	RMS(dq):  1.695e-05
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.69e-05
#
# 	Energy has increased in a minimization.
# 	Energy ratio indicates iffy step.
# 	Intrafrag trust radius decreased to 2.500e-01.
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.427e-06 	Max(dx):  5.934e-06 	RMS(dq):  1.192e-03
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.19e-03
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  3.015e-06 	Max(dx):  1.268e-05 	RMS(dq):  9.180e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 8.98e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  9.458e-06 	Max(dx):  3.250e-05 	RMS(dq):  6.064e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 5.26e-06
#
# SMILES: Cc1ccc(C(=O)[O-])cc1. Optimizing geometry...:  20%|██████                        | 1/5 [01:26<05:44, 86.09s/it]
# Optimizer: Optimization complete!
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.36e-05
#
# 	Energy has increased in a minimization.
# 	Energy ratio indicates iffy step.
# 	Intrafrag trust radius decreased to 2.500e-01.
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 7.04e-05
#
# 	Energy has increased in a minimization.
# 	Energy ratio indicates iffy step.
# 	Intrafrag trust radius decreased to 1.875e-01.
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.79e-09
#
# SMILES: O=C([O-])c1ccc(Cl)cc1. Optimizing geometry...:  40%|███████████▏                | 2/5 [03:19<05:06, 102.03s/it]
# Optimizer: Optimization complete!
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  4.371e-07 	Max(dx):  1.801e-06 	RMS(dq):  2.810e-06
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  2.348e-06 	Max(dx):  9.627e-06 	RMS(dq):  4.116e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.80e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  2.158e-06 	Max(dx):  6.555e-06 	RMS(dq):  2.838e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.32e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.812e-06 	Max(dx):  7.286e-06 	RMS(dq):  3.061e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.06e-06
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.62e-04
#
# 	Energy has increased in a minimization.
# 	Energy ratio indicates iffy step.
# 	Intrafrag trust radius decreased to 2.500e-01.
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  3.909e-06 	Max(dx):  1.464e-05 	RMS(dq):  1.331e-04
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.33e-04
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  7.623e-06 	Max(dx):  3.072e-05 	RMS(dq):  4.804e-06
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  7.398e-06 	Max(dx):  2.484e-05 	RMS(dq):  6.218e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 5.11e-06
#
# SMILES: O=C([O-])c1ccc(O)cc1. Optimizing geometry...:  60%|█████████████████▍           | 3/5 [05:00<03:23, 101.79s/it]
# Optimizer: Optimization complete!
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  5.894e-07 	Max(dx):  2.760e-06 	RMS(dq):  5.385e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 5.38e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  6.017e-07 	Max(dx):  1.914e-06 	RMS(dq):  5.045e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 4.56e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  2.916e-06 	Max(dx):  1.500e-05 	RMS(dq):  2.999e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.31e-06
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 4.24e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.740e-06 	Max(dx):  6.393e-06 	RMS(dq):  6.387e-04
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 6.39e-04
#
# 	Energy has increased in a minimization.
# 	Energy ratio indicates iffy step.
# 	Intrafrag trust radius decreased to 2.500e-01.
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  3.383e-06 	Max(dx):  1.074e-05 	RMS(dq):  4.988e-04
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 4.99e-04
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  4.509e-06 	Max(dx):  1.258e-05 	RMS(dq):  6.322e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 4.38e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  9.093e-06 	Max(dx):  3.785e-05 	RMS(dq):  6.363e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 4.96e-06
#
# SMILES: CC(=O)c1ccc(C(=O)[O-])cc1. Optimizing geometry...:  80%|███████████████████▏    | 4/5 [06:47<01:43, 103.75s/it]
# Optimizer: Optimization complete!
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  7.989e-07 	Max(dx):  2.525e-06 	RMS(dq):  3.867e-05
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.87e-05
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  3.387e-06 	Max(dx):  1.113e-05 	RMS(dq):  5.156e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 4.93e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  5.445e-06 	Max(dx):  1.445e-05 	RMS(dq):  2.954e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.53e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  5.095e-06 	Max(dx):  1.312e-05 	RMS(dq):  4.422e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.23e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.833e-06 	Max(dx):  4.708e-06 	RMS(dq):  1.400e-04
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.40e-04
#
# 	Energy has increased in a minimization.
# 	Energy ratio indicates iffy step.
# 	Intrafrag trust radius decreased to 2.500e-01.
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  4.741e-06 	Max(dx):  1.123e-05 	RMS(dq):  1.150e-04
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.15e-04
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.758e-06 	Max(dx):  7.061e-06 	RMS(dq):  3.764e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.00e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  9.706e-07 	Max(dx):  2.625e-06 	RMS(dq):  4.560e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.82e-06
#
# SMILES: CC(=O)c1ccc(C(=O)[O-])cc1. Optimizing geometry...: 100%|████████████████████████| 5/5 [09:27<00:00, 113.50s/it]
# Optimizer: Optimization complete!

# %%
# Calculate the energy differences between the acids and the bases
acid_energies = np.array(acid_energies)
base_energies = np.array(base_energies)
energy_diff = base_energies - acid_energies

# Use benzoic acid as the reference
energy_diff = energy_diff - energy_diff[0]

# Plot the energy differences
x = range(len(energy_diff))
plt.bar(x, energy_diff)
plt.xlabel('Compound')
plt.ylabel('Energy difference (kcal/mol)')
plt.axhline(0, color='black')

# %% [markdown]
# ### 8.2.3. Calculation of Potential Energy of Free Radicals

# %% [markdown]
# In the following section, we will calculate the potential energies of different free radical and compare their stability:

# %%
# Import modules
import os
import numpy as np
import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit.Chem import AllChem, Draw
from utils import View3DModel, WriteXYZString
import psi4
import py3Dmol
from tqdm import tqdm

# %%
# Create the free radicals
radical1 = Chem.MolFromSmiles('[CH3]')
radical2 = Chem.MolFromSmiles('[CH2](C)')
radical3 = Chem.MolFromSmiles('[CH](C)(C)')
radical4 = Chem.MolFromSmiles('[C](C)(C)(C)')
radical5 = Chem.MolFromSmiles('[C](C1=CC=CC=C1)(C)(C)')
radicals = [radical1, radical2, radical3, radical4, radical5]

Draw.MolsToGridImage(radicals)

# %%
# Create the molecules
mol1 = Chem.MolFromSmiles('C')
mol2 = Chem.MolFromSmiles('CC')
mol3 = Chem.MolFromSmiles('C(C)(C)')
mol4 = Chem.MolFromSmiles('C(C)(C)(C)')
mol5 = Chem.MolFromSmiles('C(C1=CC=CC=C1)(C)C')
mols = [mol1, mol2, mol3, mol4, mol5]

Draw.MolsToGridImage(mols)

# %%
# Set the number of threads and set memory limit
psi4.set_num_threads(8)
psi4.set_memory(16*1024*1024*1024) # 16 GB
# Out:
# 17179869184

# %%
# Set calculation options
psi4.set_options({
    'BASIS': '6-31++G**',
    'SCF_TYPE': 'DF',
    'REFERENCE': 'UHF' # Use UHF or ROHF for doublet state
})

# %%
radical_energies = []
radical_wfns = []

# Optimize the geometries and calculate the energies for all free radicals
progress_bar = tqdm(radicals)
for mol in progress_bar:
    smiles = Chem.MolToSmiles(mol)
    progress_bar.set_description(f'SMILES: {smiles}. Optimizing geometry...')
    
    # Prepare the molecule
    mol = Chem.AddHs(mol)
    AllChem.EmbedMolecule(mol)
    AllChem.UFFOptimizeMolecule(mol, maxIters=200)
    
    # Write the geometry to XYZ string
    charge = 0  # For free radical
    multiplicity = 2  # Doublet state
    xyz_string = WriteXYZString(mol, charge, multiplicity)

    # Get the psi4 geometry
    geometry = psi4.geometry(xyz_string)
    
    # Run geometry optimization
    max_iters = 500
    energy, wfn = psi4.optimize('b3lyp', molecule=geometry, optking__geom_maxiter=max_iters, return_wfn=True)
    radical_energies.append(energy * psi4.constants.hartree2kcalmol)
    radical_wfns.append(wfn)
# Out:
# SMILES: [CH3]. Optimizing geometry...:   0%|                                                     | 0/5 [00:00<?, ?it/s]	Change in internal coordinate of 5.92e-01 exceeds limit of 5.00e-01.
# 	Skipping Hessian update for step 1.
# 	Change in internal coordinate of 5.62e-01 exceeds limit of 5.00e-01.
# 	Skipping Hessian update for step 2.
# 	Change in internal coordinate of 7.32e-01 exceeds limit of 5.00e-01.
# 	Skipping Hessian update for step 1.
# 	Change in internal coordinate of 6.83e-01 exceeds limit of 5.00e-01.
# 	Skipping Hessian update for step 2.
# 	Change in internal coordinate of 8.52e-01 exceeds limit of 5.00e-01.
# 	Skipping Hessian update for step 1.
# SMILES: [CH2]C. Optimizing geometry...:  20%|████████▊                                   | 1/5 [00:12<00:50, 12.55s/it]
# Optimizer: Optimization complete!
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.48e-04
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.26e-07
#
# SMILES: C[CH]C. Optimizing geometry...:  40%|█████████████████▌                          | 2/5 [00:39<01:02, 20.89s/it]
# Optimizer: Optimization complete!
# SMILES: C[C](C)C. Optimizing geometry...:  60%|█████████████████████████▏                | 3/5 [01:41<01:19, 39.86s/it]
# Optimizer: Optimization complete!
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.93e-03
#
# 	Energy has increased in a minimization.
# 	Energy ratio indicates iffy step.
# 	Intrafrag trust radius decreased to 2.500e-01.
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 4.82e-08
#
# 	Energy has increased in a minimization.
# 	Energy ratio indicates iffy step.
# 	Intrafrag trust radius decreased to 2.500e-01.
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 9.92e-09
#
# SMILES: C[C](C)c1ccccc1. Optimizing geometry...:  80%|████████████████████████████       | 4/5 [03:11<00:59, 59.73s/it]
# Optimizer: Optimization complete!
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.644e-06 	Max(dx):  5.829e-06 	RMS(dq):  2.326e-03
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.33e-03
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  4.953e-06 	Max(dx):  1.586e-05 	RMS(dq):  5.958e-04
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 5.96e-04
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  2.766e-06 	Max(dx):  1.462e-05 	RMS(dq):  2.244e-04
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.24e-04
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  4.678e-06 	Max(dx):  1.683e-05 	RMS(dq):  7.485e-05
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 7.48e-05
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.478e-06 	Max(dx):  5.832e-06 	RMS(dq):  3.044e-05
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.04e-05
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.851e-06 	Max(dx):  8.504e-06 	RMS(dq):  3.130e-05
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.12e-05
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.330e-06 	Max(dx):  7.966e-06 	RMS(dq):  9.679e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 9.63e-06
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.52e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.933e-06 	Max(dx):  7.292e-06 	RMS(dq):  2.892e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.75e-06
#
# 	Energy has increased in a minimization.
# 	Energy ratio indicates iffy step.
# 	Intrafrag trust radius decreased to 2.500e-01.
# SMILES: C[C](C)c1ccccc1. Optimizing geometry...: 100%|██████████████████████████████████| 5/5 [08:38<00:00, 103.67s/it]
# Optimizer: Optimization complete!

# %%
# Set calculation options
psi4.set_options({
    'REFERENCE': 'RHF' # Use RHF for singlet state
})

# %%
mol_energies = []
mol_wfns = []

# Optimize the geometries and calculate the energies for all molecules
progress_bar = tqdm(mols)
for mol in progress_bar:
    smiles = Chem.MolToSmiles(mol)
    progress_bar.set_description(f'SMILES: {smiles}. Optimizing geometry...')
    
    # Prepare the molecule
    mol = Chem.AddHs(mol)
    AllChem.EmbedMolecule(mol)
    AllChem.UFFOptimizeMolecule(mol, maxIters=200)
    
    # Write the geometry to XYZ string
    xyz_string = Chem.MolToXYZBlock(mol)

    # Get the psi4 geometry
    geometry = psi4.geometry(xyz_string)
    
    # Run geometry optimization
    max_iters = 500
    energy, wfn = psi4.optimize('b3lyp', molecule=geometry, optking__geom_maxiter=max_iters, return_wfn=True)
    mol_energies.append(energy * psi4.constants.hartree2kcalmol)
    mol_wfns.append(wfn)
# Out:
# SMILES: CC. Optimizing geometry...:  20%|█████████▌                                      | 1/5 [00:02<00:11,  2.95s/it]
# Optimizer: Optimization complete!
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.52e-04
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 7.75e-07
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.52e-07
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 4.85e-07
#
# SMILES: CCC. Optimizing geometry...:  40%|██████████████████▊                            | 2/5 [00:12<00:19,  6.59s/it]
# Optimizer: Optimization complete!
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.89e-04
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.660e-06 	Max(dx):  5.468e-06 	RMS(dq):  3.091e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.65e-06
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.71e-06
#
# SMILES: CC(C)C. Optimizing geometry...:  60%|██████████████████████████▍                 | 3/5 [00:24<00:18,  9.44s/it]
# Optimizer: Optimization complete!
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.66e-04
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  9.106e-07 	Max(dx):  3.674e-06 	RMS(dq):  9.478e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 9.43e-06
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.94e-07
#
# SMILES: CC(C)c1ccccc1. Optimizing geometry...:  80%|█████████████████████████████▌       | 4/5 [00:49<00:15, 15.56s/it]
# Optimizer: Optimization complete!
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  2.078e-06 	Max(dx):  7.466e-06 	RMS(dq):  1.041e-04
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.04e-04
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  3.089e-06 	Max(dx):  1.303e-05 	RMS(dq):  1.584e-05
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 1.57e-05
#
# 	Energy has increased in a minimization.
# 	Energy ratio indicates iffy step.
# 	Intrafrag trust radius decreased to 2.500e-01.
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  2.006e-06 	Max(dx):  7.994e-06 	RMS(dq):  3.185e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.80e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  1.273e-06 	Max(dx):  4.948e-06 	RMS(dq):  3.722e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.65e-06
#
# 	Unable to completely converge to displaced geometry.
# 	RMS(dx):  6.680e-06 	Max(dx):  1.859e-05 	RMS(dq):  3.466e-06
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 3.26e-06
#
# SMILES: CC(C)c1ccccc1. Optimizing geometry...: 100%|█████████████████████████████████████| 5/5 [02:34<00:00, 30.97s/it]
# Optimizer: Optimization complete!

# %%
# Calculate the energy differences between the free radicals and the molecules
radical_energies = np.array(radical_energies)
mol_energies = np.array(mol_energies)
energy_diff = radical_energies - mol_energies

# Use methyl free radical as the reference
energy_diff = energy_diff - energy_diff[0]

# Plot the energy differences
x = range(len(energy_diff))
plt.bar(x, energy_diff)
plt.xlabel('Free radical')
plt.ylabel('Energy difference (kcal/mol)')
plt.axhline(0, color='black')
